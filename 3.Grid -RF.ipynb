# %%
# Grid random forest regressor model
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={"criterion":["squared_error","absolute_error","friedman_mse","poisson"],"n_estimators":[10,50,100],"max_features":["sqrt","log2","None"]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\ARUN\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ARUN\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ARUN\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 458, in fit
#     for i, t in enumerate(trees)
# ...

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8698625852660685

# %%
re=grid.cv_results_

# %%
print("The R_score value for best parameters {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameters {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}: 0.8698625852660685

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.039062      0.012506         0.008400    9.975764e-04
# 1        0.111327      0.003383         0.013282    7.813931e-04
# 2        0.213868      0.011928         0.020703    3.912935e-04
# 3        0.029491      0.000956         0.007617    7.303848e-04
# 4        0.109765      0.002591         0.013281    7.812739e-04
# 5        0.212109      0.012282         0.021876    2.439349e-03
# 6        0.015039      0.001811         0.000000    0.000000e+00
# 7        0.041016      0.002621         0.000000    0.000000e+00
# 8        0.066992      0.002734         0.000000    0.000000e+00
# 9        0.097264      0.005406         0.007129    5.852226e-04
# 10       0.480664      0.016939         0.015235    4.786305e-04
# 11       0.913672      0.081951         0.019922    9.960052e-04
# 12       0.095311      0.009719         0.006836    4.623108e-07
# ...

# %%
age=int(input("AGE:"))
bmi=float(input("BMI:"))
childern=int(input("CHILDERN:"))
sex=int(input("MALE 1 or FEMALE 0:"))
smoker=int(input("SMOKER 1 or NON-SMOKER 0:"))
# Out:
# AGE:23
# BMI:20
# CHILDERN:1
# MALE 1 or FEMALE 0:1
# SMOKER 1 or NON-SMOKER 0:0

# %%
Future_prediction=grid.predict([[age,bmi,childern,sex,smoker]])
print("Future_prediction{}:".format(Future_prediction))
# Out:
# Future_prediction[2933.6114032]:
# C:\Users\ARUN\Anaconda3\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   "X does not have valid feature names, but"

# %%
r_score
# Out:
# 0.8698625852660685

# %%
import pickle
filename="final_model_grid_random_forest.sav"
pickle.dump(grid,open(filename,"wb"))
